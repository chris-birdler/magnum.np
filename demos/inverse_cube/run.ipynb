# %% [markdown]
# # Inverse Cube

# %% [markdown]
# ## Google Colab Link
#
# The demo can be run on Google Colab without any local installation.
# Use the following [link](https://colab.research.google.com/drive/1X7zQKKHrHPBubhHg-8B2o_bfFun4uBwN) to try it out.

# %%
# !pip install -q magnumnp numpy==1.22.4

# %% [markdown]
# ## Run Demo:

# %%
from magnumnp import *
import torch
from torch import sin, cos

Timer.enable()

# initialize mesh
n  = (10, 10, 10)
dx = (5e-9, 5e-9, 5e-9)
mesh = Mesh(n, dx)
h = 300e-3/constants.mu_0
tf = 1e-9
dt = 1e-12

# initialize state
state = State(mesh)
state.material = {
    "Ms": 8e5,
    "A": 1.3e-11,
    "alpha": 1,
    "Ku": 1e5,
    "Ku_axis": state.Tensor([0,0,1])
    }

m0 = state.Constant([0,0,0])
m0[:, :, :, 2] = 1
m0[:n[0]//2, :, :, 0] = 0.1
m0[n[0]//2:, :, :, 0] = -0.1
m0.normalize()

m_t = state.Constant([1,0,1])
m_t.normalize()

state.phi = state.Tensor([1.5708], requires_grad = True)
state.theta = state.Tensor([1.5708], requires_grad = True)

h_ext = lambda t: torch.stack([h*sin(state.theta)*cos(state.phi),
                               h*sin(state.theta)*sin(state.phi),
                               h*cos(state.theta)], dim=-1)

demag    = DemagField()
exchange = ExchangeField()
aniso    = UniaxialAnisotropyField()

# relax system
with torch.no_grad():
    state.m = m0
    llg = LLGSolver([demag, exchange, aniso])
    llg.relax(state)
    m0 = state.m
    write_vti(m0, "data/m0.vti")


# start optimization
external = ExternalField(h_ext)
llg = LLGSolver([demag, exchange, aniso, external], solver = TorchDiffEqAdjoint, adjoint_parameters = (state.phi, state.theta))

phi_grad = ("phi_grad", lambda state: state.phi.grad)
theta_grad = ("theta_grad", lambda state: state.theta.grad)
epoch_logger = ScalarLogger("data/epoch.dat", ["phi", "theta", "loss", phi_grad, theta_grad])

optimizer = torch.optim.Adam([state.phi, state.theta], lr=0.05)
my_loss = torch.nn.L1Loss()

for epoch in range(100):
    print("epoch: ", epoch)

    optimizer.zero_grad()
    state.m = m0
    state.t = 0.

    logger = ScalarLogger("data/m_%03d.dat" % epoch, ['t', 'm'])
    with Timer("forward"):
        while state.t < tf:
            llg.step(state, dt)
            logger << state

    with Timer("backward"):
        state.loss = my_loss(state.m, m_t)
        state.loss.backward()

    optimizer.step()

    epoch_logger << state

Timer.print_report()
# Out:
# 2023-05-15 08:16:07  magnum.np:INFO magnum.np 1.0.9
# 2023-05-15 08:16:07  magnum.np:INFO [State] running on device: cpu (dtype = float64)
# 2023-05-15 08:16:07  magnum.np:INFO [Mesh] 10x10x10 (size= 5e-09 x 5e-09 x 5e-09)
# 2023-05-15 08:16:08  magnum.np:INFO [LLGSolver] using RKF45 solver (atol = 1e-05)
# 2023-05-15 08:16:09  magnum.np:INFO [DEMAG]: Time calculation of demag kernel = 1.7393743991851807 s
# Process ForkProcess-4:
# Process ForkProcess-8:
# Process ForkProcess-7:
# Process ForkProcess-5:
# Process ForkProcess-2:
# Process ForkProcess-6:
# Process ForkProcess-3:
# Process ForkProcess-1:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/usr/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/usr/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/usr/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/usr/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/usr/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/usr/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
# KeyboardInterrupt
#   File "/usr/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.8/multiprocessing/queues.py", line 97, in get
#     res = self._recv_bytes()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
#   File "/usr/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/usr/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/git/magnum.np/magnumnp/common/timer.py:236, in timedmethod.<locals>.timed(*args, **kwargs)
#     235 with Timer("%s.%s" % (args[0].__class__.__name__, method.__name__)):
# --> 236     return method(*args, **kwargs)
#
# File ~/git/magnum.np/magnumnp/field_terms/exchange.py:53, in ExchangeField.h(self, state)
#      52 dz = state.dx[2].reshape(1,1,-1,1)
# ---> 53 h = self._h(m, A, Ms, dx, dy, dz, state)
#      54 return state.Tensor(h)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:254, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     253 try:
# --> 254     return fn(*args, **kwargs)
#     255 finally:
#
# File ~/git/magnum.np/magnumnp/field_terms/exchange.py:58, in ExchangeField._h(self, m, A, Ms, dx, dy, dz, state)
#      56 @torch.compile
#      57 def _h(self, m, A, Ms, dx, dy, dz, state):
# ---> 58     h = state._zeros(state.mesh.n + (3,))
#      60     A_avg = 2.*A[1:,:,:]*A[:-1,:,:] / (A[1:,:,:]*dx[:-1,:,:,:] + A[:-1,:,:]*dx[1:,:,:,:])
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:391, in catch_errors_wrapper.<locals>.catch_errors(frame, cache_size)
#     390 with compile_lock:
# --> 391     return callback(frame, cache_size, hooks)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/convert_frame.py:406, in convert_frame.<locals>._convert_frame(frame, cache_size, hooks)
#     405 try:
# --> 406     result = inner_convert(frame, cache_size, hooks)
#     407     counters["frames"]["ok"] += 1
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/convert_frame.py:105, in wrap_convert_context.<locals>._fn(*args, **kwargs)
#     104 try:
# --> 105     return fn(*args, **kwargs)
#     106 finally:
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/convert_frame.py:263, in convert_frame_assert.<locals>._convert_frame_assert(frame, cache_size, hooks)
#     261 initial_grad_state = torch.is_grad_enabled()
# --> 263 return _compile(
#     264     frame.f_code,
#     265     frame.f_globals,
#     266     frame.f_locals,
#     267     frame.f_builtins,
#     268     compiler_fn,
#     269     one_graph,
#     270     export,
#     271     hooks,
#     272     frame,
#     273 )
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/utils.py:164, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     163 t0 = time.time()
# --> 164 r = func(*args, **kwargs)
#     165 time_spent = time.time() - t0
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/convert_frame.py:326, in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, hooks, frame)
#     325 try:
# --> 326     out_code = transform_code_object(code, transform)
#     327     orig_code_map[out_code] = code
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/bytecode_transformation.py:530, in transform_code_object(code, transformations, safe)
#     528 propagate_line_nums(instructions)
# --> 530 transformations(instructions, code_options)
#     531 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/convert_frame.py:313, in _compile.<locals>.transform(instructions, code_options)
#     312 with tracing(tracer.output.tracing_context):
# --> 313     tracer.run()
#     314 output = tracer.output
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/symbolic_convert.py:1841, in InstructionTranslator.run(self)
#    1840 _step_logger()(logging.INFO, f"torchdynamo start tracing {self.f_code.co_name}")
# -> 1841 super().run()
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/symbolic_convert.py:597, in InstructionTranslatorBase.run(self)
#     593 self.output.push_tx(self)
#     594 while (
#     595     self.instruction_pointer is not None
#     596     and not self.output.should_exit
# --> 597     and self.step()
#     598 ):
#     599     pass
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/symbolic_convert.py:560, in InstructionTranslatorBase.step(self)
#     559     unimplemented(f"missing: {inst.opname}")
# --> 560 getattr(self, inst.opname)(inst)
#     562 return inst.opname != "RETURN_VALUE"
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/symbolic_convert.py:1920, in InstructionTranslator.RETURN_VALUE(self, inst)
#    1919 log.debug("RETURN_VALUE triggered compile")
# -> 1920 self.output.compile_subgraph(
#    1921     self, reason=GraphCompileReason("return_value", [self.frame_summary()])
#    1922 )
#    1923 self.output.add_output_instructions([create_instruction("RETURN_VALUE")])
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/output_graph.py:545, in OutputGraph.compile_subgraph(self, tx, partial_convert, reason)
#     534 if (
#     535     stack_values
#     536     and all(
#    (...)
#     542 ):
#     543     # optimization to generate better code in a common case
#     544     self.add_output_instructions(
# --> 545         self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
#     546         + [create_instruction("UNPACK_SEQUENCE", len(stack_values))]
#     547     )
#     548 else:
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/output_graph.py:615, in OutputGraph.compile_and_call_fx_graph(self, tx, rv, root)
#     614 assert_no_fake_params_or_buffers(gm)
# --> 615 compiled_fn = self.call_user_compiler(gm)
#     616 compiled_fn = disable(compiled_fn)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/utils.py:164, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     163 t0 = time.time()
# --> 164 r = func(*args, **kwargs)
#     165 time_spent = time.time() - t0
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/output_graph.py:697, in OutputGraph.call_user_compiler(self, gm)
#     696 else:
# --> 697     compiled_fn = compiler_fn(gm, self.fake_example_inputs())
#     698 _step_logger()(logging.INFO, f"done compiler function {name}")
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/debug_utils.py:1064, in wrap_backend_debug.<locals>.debug_wrapper(gm, example_inputs, **kwargs)
#    1063 else:
# -> 1064     compiled_gm = compiler_fn(gm, example_inputs)
#    1066 return compiled_gm
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/__init__.py:1382, in _TorchCompileInductorWrapper.__call__(self, model_, inputs_)
#    1380 from torch._inductor.compile_fx import compile_fx
# -> 1382 return compile_fx(model_, inputs_, config_patches=self.config)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/compile_fx.py:488, in compile_fx(model_, example_inputs_, inner_compile, config_patches, decompositions)
#     485 # TODO: can add logging before/after the call to create_aot_dispatcher_function
#     486 # in torch._functorch/aot_autograd.py::aot_module_simplified::aot_function_simplified::new_func
#     487 # once torchdynamo is merged into pytorch
# --> 488 return aot_autograd(
#     489     fw_compiler=fw_compiler,
#     490     bw_compiler=bw_compiler,
#     491     decompositions=decompositions,
#     492     partition_fn=functools.partial(
#     493         min_cut_rematerialization_partition, compiler="inductor"
#     494     ),
#     495     keep_inference_input_mutations=True,
#     496 )(model_, example_inputs_)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/backends/common.py:48, in aot_autograd.<locals>.compiler_fn(gm, example_inputs)
#      47 with enable_aot_logging():
# ---> 48     cg = aot_module_simplified(gm, example_inputs, **kwargs)
#      49     counters["aot_autograd"]["ok"] += 1
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_functorch/aot_autograd.py:2874, in aot_module_simplified(mod, args, fw_compiler, bw_compiler, partition_fn, decompositions, hasher_type, static_argnums, keep_inference_input_mutations)
#    2863 aot_config = AOTConfig(
#    2864     fw_compiler=fw_compiler,
#    2865     bw_compiler=bw_compiler,
#    (...)
#    2871     dynamic_shapes=dynamic_shapes
#    2872 )
# -> 2874 compiled_fn = create_aot_dispatcher_function(
#    2875     functional_call,
#    2876     full_args,
#    2877     aot_config,
#    2878 )
#    2880 # TODO: There is something deeply wrong here; compiled_fn running with
#    2881 # the boxed calling convention, but aot_module_simplified somehow
#    2882 # historically returned a function that was not the boxed calling
#    2883 # convention.  This should get fixed...
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/utils.py:164, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     163 t0 = time.time()
# --> 164 r = func(*args, **kwargs)
#     165 time_spent = time.time() - t0
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_functorch/aot_autograd.py:2555, in create_aot_dispatcher_function(flat_fn, flat_args, aot_config)
#    2553 # You can put more passes here
# -> 2555 compiled_fn = compiler_fn(flat_fn, fake_flat_args, aot_config)
#    2557 if not hasattr(compiled_fn, "_boxed_call"):
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_functorch/aot_autograd.py:1735, in aot_wrapper_dedupe(flat_fn, flat_args, aot_config, compiler_fn)
#    1734     if ok:
# -> 1735         return compiler_fn(flat_fn, leaf_flat_args, aot_config)
#    1737 # Strategy 2: Duplicate specialize.
#    1738 #
#    1739 # In Haskell types, suppose you have:
#    (...)
#    1771 #   }
#    1772 #   keep_arg_mask = [True, True, False, True]
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_functorch/aot_autograd.py:1346, in aot_dispatch_base(flat_fn, flat_args, aot_config)
#    1345 with context(), track_graph_compiling(aot_config, "inference"):
# -> 1346     compiled_fw = aot_config.fw_compiler(fw_module, flat_args_with_views_handled)
#    1348 compiled_fn = create_runtime_wrapper(
#    1349     compiled_fw,
#    1350     runtime_metadata=metadata_,
#    1351     trace_joint=False,
#    1352     keep_input_mutations=aot_config.keep_inference_input_mutations
#    1353 )
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/utils.py:164, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     163 t0 = time.time()
# --> 164 r = func(*args, **kwargs)
#     165 time_spent = time.time() - t0
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/compile_fx.py:462, in compile_fx.<locals>.fw_compiler(model, example_inputs)
#     461 model = convert_outplace_to_inplace(model)
# --> 462 return inner_compile(
#     463     model,
#     464     example_inputs,
#     465     num_fixed=fixed,
#     466     cudagraphs=cudagraphs,
#     467     graph_id=graph_id,
#     468 )
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/debug_utils.py:598, in wrap_compiler_debug.<locals>.debug_wrapper(gm, example_inputs, **kwargs)
#     597 else:
# --> 598     compiled_fn = compiler_fn(gm, example_inputs)
#     600 return compiled_fn
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/debug.py:239, in DebugContext.wrap.<locals>.inner(*args, **kwargs)
#     238 with DebugContext():
# --> 239     return fn(*args, **kwargs)
#
# File /usr/lib/python3.8/contextlib.py:75, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      74 with self._recreate_cm():
# ---> 75     return func(*args, **kwds)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/compile_fx.py:180, in compile_fx_inner(gm, example_inputs, cudagraphs, num_fixed, is_backward, graph_id)
#     179         graph.run(*example_inputs)
# --> 180         compiled_fn = graph.compile_to_fn()
#     182 if cudagraphs:
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/graph.py:633, in GraphLowering.compile_to_fn(self)
#     632 def compile_to_fn(self):
# --> 633     return self.compile_to_module().call
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/utils.py:164, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     163 t0 = time.time()
# --> 164 r = func(*args, **kwargs)
#     165 time_spent = time.time() - t0
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/graph.py:618, in GraphLowering.compile_to_module(self)
#     616 from .codecache import PyCodeCache
# --> 618 code = self.codegen()
#     619 if config.debug:
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/graph.py:567, in GraphLowering.codegen(self)
#     565 self.init_wrapper_code()
# --> 567 self.scheduler = Scheduler(self.buffers)
#     568 assert self.scheduler is not None  # mypy can't figure this out
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_dynamo/utils.py:164, in dynamo_timed.<locals>.dynamo_timed_inner.<locals>.time_wrapper(*args, **kwargs)
#     163 t0 = time.time()
# --> 164 r = func(*args, **kwargs)
#     165 time_spent = time.time() - t0
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/scheduler.py:636, in Scheduler.__init__(self, nodes)
#     635     group_fn = self.get_backend(node.get_device()).group_fn
# --> 636     self.nodes.append(SchedulerNode(self, node, group_fn))
#     637 elif isinstance(node, ir.ExternKernel):
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/scheduler.py:357, in SchedulerNode.__init__(self, scheduler, node, group_fn)
#     353 super().__init__(scheduler, node)
#     354 (
#     355     self._sizes,
#     356     self._body,
# --> 357 ) = node.simplify_and_reorder()
#     359 self.group = (node.get_device(), group_fn(self._sizes))
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/ir.py:2172, in ComputedBuffer.simplify_and_reorder(self)
#    2171 with patch.object(ConstantBuffer, "override_device", self.get_device()):
# -> 2172     body = LoopBody(
#    2173         self.get_store_function(),
#    2174         (args if self.get_reduction_type() else args[:1]),
#    2175         var_ranges,
#    2176     )
#    2177 index_formulas = [*body.indexing_exprs.values()]
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/ir.py:4023, in LoopBody.__init__(self, fn, args, var_ranges)
#    4022 self.indirect_vars = []
# -> 4023 self.root_block = LoopBodyBlock(self, fn, args)
#    4024 self.indexing = None
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/ir.py:4172, in LoopBodyBlock.__init__(self, body, fn, args)
#    4169 with V.set_ops_handler(
#    4170     SimplifyIndexing(CaptureIndexing(proxy_ops), self.body.var_ranges)
#    4171 ):
# -> 4172     tracer.create_proxy("output", "output", (fn(*args),), {})
#    4173 self.graph = tracer.graph
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/ir.py:434, in Pointwise.store_output(self, output_name, indexer, vars)
#     433 def store_output(self, output_name, indexer, vars):
# --> 434     return ops.store(output_name, indexer(vars), self.inner_fn(vars))
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/lowering.py:1557, in slice_scatter.<locals>.inner_fn(idx)
#    1555 if start == 0 and end == dim_size and step == 1:
#    1556     # selecting every element is the same as just src.clone()
# -> 1557     return src_loader(idx)
#    1559 idx_dim = ops.index_expr(idx[dim], torch.int32)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/lowering.py:1589, in slice_scatter.<locals>.inner_fn(idx)
#    1588 mask = functools.reduce(ops.and_, mask)
# -> 1589 src_val = ops.masked(
#    1590     mask,
#    1591     lambda: src_loader(src_idx),
#    1592     0 if is_integer_type(x) else 0.0,
#    1593 )
#    1594 return ops.where(
#    1595     mask,
#    1596     src_val,
#    1597     x_loader(idx),
#    1598 )
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/ir.py:4139, in LoopBodyBlock.__init__.<locals>.CaptureIndexing.masked(mask_proxy, masked_body, other_proxy)
#    4138 name = self.body.add_submodule(shim, "masked_subblock")
# -> 4139 subblock = LoopBodyBlock(self.body, masked_body, [])
#    4140 self.body.subblocks[name] = subblock
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/ir.py:4172, in LoopBodyBlock.__init__(self, body, fn, args)
#    4169 with V.set_ops_handler(
#    4170     SimplifyIndexing(CaptureIndexing(proxy_ops), self.body.var_ranges)
#    4171 ):
# -> 4172     tracer.create_proxy("output", "output", (fn(*args),), {})
#    4173 self.graph = tracer.graph
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/lowering.py:1591, in slice_scatter.<locals>.inner_fn.<locals>.<lambda>()
#    1588 mask = functools.reduce(ops.and_, mask)
#    1589 src_val = ops.masked(
#    1590     mask,
# -> 1591     lambda: src_loader(src_idx),
#    1592     0 if is_integer_type(x) else 0.0,
#    1593 )
#    1594 return ops.where(
#    1595     mask,
#    1596     src_val,
#    1597     x_loader(idx),
#    1598 )
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/lowering.py:1557, in slice_scatter.<locals>.inner_fn(idx)
#    1555 if start == 0 and end == dim_size and step == 1:
#    1556     # selecting every element is the same as just src.clone()
# -> 1557     return src_loader(idx)
#    1559 idx_dim = ops.index_expr(idx[dim], torch.int32)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/lowering.py:1557, in slice_scatter.<locals>.inner_fn(idx)
#    1555 if start == 0 and end == dim_size and step == 1:
#    1556     # selecting every element is the same as just src.clone()
# -> 1557     return src_loader(idx)
#    1559 idx_dim = ops.index_expr(idx[dim], torch.int32)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/lowering.py:349, in make_pointwise.<locals>.inner.<locals>.inner_fn(index)
#     348 else:
# --> 349     return fn(*[load(index) for load in loaders])
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/lowering.py:349, in <listcomp>(.0)
#     348 else:
# --> 349     return fn(*[load(index) for load in loaders])
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/ir.py:1466, in View.make_loader.<locals>.load(index)
#    1465 def load(index):
# -> 1466     return inner(self.reindex(index))
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/lowering.py:1557, in slice_scatter.<locals>.inner_fn(idx)
#    1555 if start == 0 and end == dim_size and step == 1:
#    1556     # selecting every element is the same as just src.clone()
# -> 1557     return src_loader(idx)
#    1559 idx_dim = ops.index_expr(idx[dim], torch.int32)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/lowering.py:1559, in slice_scatter.<locals>.inner_fn(idx)
#    1557     return src_loader(idx)
# -> 1559 idx_dim = ops.index_expr(idx[dim], torch.int32)
#    1560 src_idx = list(idx)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/sizevars.py:619, in SimplifyIndexing.index_expr(self, index, dtype)
#     618 def index_expr(self, index, dtype):
# --> 619     return self._inner.index_expr(self._simplify(index), dtype)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/_inductor/ir.py:4127, in LoopBodyBlock.__init__.<locals>.CaptureIndexing.index_expr(self, index, dtype)
#    4126 index = add_index(index, "other")
# -> 4127 return self._inner.index_expr(index, dtype)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/fx/proxy.py:468, in Attribute.__call__(self, *args, **kwargs)
#     467 def __call__(self, *args, **kwargs):
# --> 468     return self.tracer.create_proxy('call_method', self.attr, (self.root,) + args, kwargs)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/fx/proxy.py:169, in TracerBase.create_proxy(self, kind, target, args, kwargs, name, type_expr, proxy_factory_fn)
#     167 assert isinstance(kwargs_, dict)
# --> 169 node = self.create_node(kind, target, args_, kwargs_, name, type_expr)
#     171 if not proxy_factory_fn:
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/fx/proxy.py:122, in TracerBase.create_node(self, kind, target, args, kwargs, name, type_expr)
#     120     check_for_mutable_operation(target, args, kwargs)
# --> 122 node = self.graph.create_node(kind, target, args, kwargs, name, type_expr)
#     123 # TODO node_name_to_scope will be depricated in favor of
#     124 # node.meta['nn_module_stack']
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/fx/graph.py:835, in Graph.create_node(self, op, target, args, kwargs, name, type_expr)
#     833 assert isinstance(kwargs, dict), "kwargs must be a dict"
# --> 835 candidate = name if name is not None else self._target_to_str(target)
#     836 name = self._graph_namespace.create_name(candidate, None)
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/fx/graph.py:1195, in Graph._target_to_str(self, target)
#    1194         op = op[2:-2]
# -> 1195 op = _snake_case(op)
#    1196 return op
#
# File ~/git/magnum.np/venv/lib/python3.8/site-packages/torch/fx/graph.py:88, in _snake_case(s)
#      87     chars.append('_')
# ---> 88 chars.append(c.lower())
#      89 prev_lower = c.islower()
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/git/magnum.np/magnumnp/common/timer.py:236, in timedmethod.<locals>.timed(*args, **kwargs)
#     235 with Timer("%s.%s" % (args[0].__class__.__name__, method.__name__)):
# --> 236     return method(*args, **kwargs)
#
# File ~/git/magnum.np/magnumnp/solvers/llg.py:55, in LLGSolver.relax(self, state, maxiter, rtol, dt)
#      54 t0 = state.t
# ---> 55 E0 = self.E(state)
#      57 for i in range(maxiter):
#
# File ~/git/magnum.np/magnumnp/solvers/llg.py:45, in LLGSolver.E(self, state)
#      44 def E(self, state):
# ---> 45     return sum([term.E(state) for term in self._terms])
#
# File ~/git/magnum.np/magnumnp/solvers/llg.py:45, in <listcomp>(.0)
#      44 def E(self, state):
# ---> 45     return sum([term.E(state) for term in self._terms])
#
# File ~/git/magnum.np/magnumnp/field_terms/field_terms.py:48, in LinearFieldTerm.E(self, state)
#      47 def E(self, state):
# ---> 48     return -0.5 * constants.mu_0 * state.mesh.cell_volume * torch.sum(state.material["Ms"] * state.m * self.h(state))
#
# File ~/git/magnum.np/magnumnp/common/timer.py:236, in timedmethod.<locals>.timed(*args, **kwargs)
#     235 with Timer("%s.%s" % (args[0].__class__.__name__, method.__name__)):
# --> 236     return method(*args, **kwargs)
#
# File ~/git/magnum.np/magnumnp/common/timer.py:103, in Timer.__exit__(self, e_typ, e_val, trcbak)
#     102 if all((e_typ, e_val, trcbak)):
# --> 103     raise e_typ from e_val
#     105 if not Timer._options['active']: return self
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 49
#      47 state.m = m0
#      48 llg = LLGSolver([demag, exchange, aniso])
# ---> 49 llg.relax(state)
#      50 m0 = state.m
#      51 write_vti(m0, "data/m0.vti")
#
# File ~/git/magnum.np/magnumnp/common/timer.py:236, in timedmethod.<locals>.timed(*args, **kwargs)
#     233 @wraps(method)
#     234 def timed(*args, **kwargs):
#     235     with Timer("%s.%s" % (args[0].__class__.__name__, method.__name__)):
# --> 236         return method(*args, **kwargs)
#
# File ~/git/magnum.np/magnumnp/common/timer.py:103, in Timer.__exit__(self, e_typ, e_val, trcbak)
#     101 def __exit__(self, e_typ, e_val, trcbak):
#     102     if all((e_typ, e_val, trcbak)):
# --> 103         raise e_typ from e_val
#     105     if not Timer._options['active']: return self
#     107     if Timer._options['skip'] <= self._data['calls']:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Plot Results

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('data/epoch.dat')
phi, theta, loss, phi_grad, theta_grad = data.T

plt.plot(theta)
plt.show()
