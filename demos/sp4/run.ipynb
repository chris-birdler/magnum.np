# %% [markdown]
# # muMAG Standard Problem #4
#
# A detailed problem description can be found [here](https://www.ctcms.nist.gov/~rdm/std4/spec4.html)

# %% [markdown]
# ## Google Colab Link
#
# The demo can be run on Google Colab without any local installation.
# Use the following [link](https://colab.research.google.com/drive/1UNdTe5y41k_6HrZ7WsNASQSs5viUMzss) to try out.

# %% [markdown]
# ## Install magnum.np and mount Google Drive:

# %%
# !pip install -q magnumnp
# !pip install -q matplotlib

# %%
# Mount Google Drive to run on Colab
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    # %cd '/content/drive/MyDrive/Colab Notebooks/sp4'
except:
    pass

# %% [markdown]
# ## Run Demo:

# %%
#TODO: read latest script content from gitlab repository, as soon as %load works with Colab
from magnumnp import *
import torch

Timer.enable(log_mem = True)

# initialize mesh
eps = 1e-15
n  = (100, 25, 1)
dx = (5e-9, 5e-9, 3e-9)
mesh = Mesh(n, dx)
state = State(mesh)

state.material = {
    "Ms": 8e5,
    "A": 1.3e-11,
    "alpha": 0.02
    }

# initialize field terms
demag    = DemagField()
exchange = ExchangeField()
external = ExternalField([-24.6e-3/constants.mu_0,
                          +4.3e-3/constants.mu_0,
                          0.0])

# initialize magnetization that relaxes into s-state
state.m = state.Constant([0,0,0])
state.m[1:-1,:,:,0]   = 1.0
state.m[(-1,0),:,:,1] = 1.0

# relax without external field
llg = LLGSolver([demag, exchange])
llg.relax(state)
write_vti(state.m, "data/m0.vti", state)

# perform integration with external field
llg = LLGSolver([demag, exchange, external])
logger = Logger("data", ['t', 'm'])
while state.t < 1e-9-eps:
    llg.step(state, 1e-11)
    logger << state

Timer.print_report()
# Out:
# 2023-02-17 09:15:31  magnum.np:INFO magnum.np 1.0.5
# /home/florian/.local/lib/python3.8/site-packages/torch/cuda/__init__.py:82: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:112.)
#   return torch._C._cuda_getDeviceCount() > 0
# 2023-02-17 09:15:31  magnum.np:INFO [State] running on device: cpu (dtype = float32)
# 2023-02-17 09:15:31  magnum.np:INFO [Mesh] 100x25x1 (size= 5e-09 x 5e-09 x 3e-09)
# 2023-02-17 09:15:31  magnum.np:INFO [LLGSolver] using RKF45 solver (atol = 1e-05)
# 2023-02-17 09:15:31  magnum.np:INFO [DEMAG]: Time calculation of demag kernel = 0.36252617835998535 s
# 2023-02-17 09:15:31  magnum.np:INFO [LLG] relax: t=1e-11 dE=3.992 E=9.25329e-19
# 2023-02-17 09:15:31  magnum.np:INFO [LLG] relax: t=2e-11 dE=0.267094 E=7.30277e-19
# 2023-02-17 09:15:31  magnum.np:INFO [LLG] relax: t=3e-11 dE=0.0521441 E=6.94084e-19
# 2023-02-17 09:15:31  magnum.np:INFO [LLG] relax: t=4e-11 dE=0.0178207 E=6.81932e-19
# 2023-02-17 09:15:31  magnum.np:INFO [LLG] relax: t=5e-11 dE=0.00873075 E=6.76029e-19
# 2023-02-17 09:15:32  magnum.np:INFO [LLG] relax: t=6e-11 dE=0.00554699 E=6.723e-19
# 2023-02-17 09:15:32  magnum.np:INFO [LLG] relax: t=7e-11 dE=0.00414781 E=6.69523e-19
# 2023-02-17 09:15:32  magnum.np:INFO [LLG] relax: t=8e-11 dE=0.00339818 E=6.67256e-19
# 2023-02-17 09:15:32  magnum.np:INFO [LLG] relax: t=9e-11 dE=0.00292837 E=6.65307e-19
# 2023-02-17 09:15:32  magnum.np:INFO [LLG] relax: t=1e-10 dE=0.00259903 E=6.63583e-19
# 2023-02-17 09:15:32  magnum.np:INFO [LLG] relax: t=1.1e-10 dE=0.00235056 E=6.62027e-19
# 2023-02-17 09:15:32  magnum.np:INFO [LLG] relax: t=1.2e-10 dE=0.00215473 E=6.60603e-19
# 2023-02-17 09:15:32  magnum.np:INFO [LLG] relax: t=1.3e-10 dE=0.00199491 E=6.59288e-19
# 2023-02-17 09:15:32  magnum.np:INFO [LLG] relax: t=1.4e-10 dE=0.00186239 E=6.58062e-19
# 2023-02-17 09:15:32  magnum.np:INFO [LLG] relax: t=1.5e-10 dE=0.00175107 E=6.56912e-19
# 2023-02-17 09:15:32  magnum.np:INFO [LLG] relax: t=1.6e-10 dE=0.00165567 E=6.55826e-19
# 2023-02-17 09:15:32  magnum.np:INFO [LLG] relax: t=1.7e-10 dE=0.00157332 E=6.54796e-19
# 2023-02-17 09:15:33  magnum.np:INFO [LLG] relax: t=1.8e-10 dE=0.00150151 E=6.53814e-19
# 2023-02-17 09:15:33  magnum.np:INFO [LLG] relax: t=1.9e-10 dE=0.00143786 E=6.52876e-19
# 2023-02-17 09:15:33  magnum.np:INFO [LLG] relax: t=2e-10 dE=0.00138085 E=6.51975e-19
# 2023-02-17 09:15:33  magnum.np:INFO [LLG] relax: t=2.1e-10 dE=0.00132878 E=6.5111e-19
# 2023-02-17 09:15:33  magnum.np:INFO [LLG] relax: t=2.2e-10 dE=0.00128103 E=6.50277e-19
# 2023-02-17 09:15:33  magnum.np:INFO [LLG] relax: t=2.3e-10 dE=0.00123612 E=6.49474e-19
# 2023-02-17 09:15:33  magnum.np:INFO [LLG] relax: t=2.4e-10 dE=0.00119361 E=6.487e-19
# 2023-02-17 09:15:33  magnum.np:INFO [LLG] relax: t=2.5e-10 dE=0.00115293 E=6.47953e-19
# 2023-02-17 09:15:33  magnum.np:INFO [LLG] relax: t=2.6e-10 dE=0.00111356 E=6.47232e-19
# 2023-02-17 09:15:33  magnum.np:INFO [LLG] relax: t=2.7e-10 dE=0.00107486 E=6.46537e-19
# 2023-02-17 09:15:33  magnum.np:INFO [LLG] relax: t=2.8e-10 dE=0.00103707 E=6.45867e-19
# 2023-02-17 09:15:34  magnum.np:INFO [LLG] relax: t=2.9e-10 dE=0.000999887 E=6.45222e-19
# 2023-02-17 09:15:34  magnum.np:INFO [LLG] relax: t=3e-10 dE=0.000962914 E=6.44602e-19
# 2023-02-17 09:15:34  magnum.np:INFO [LLG] relax: t=3.1e-10 dE=0.000926316 E=6.44005e-19
# 2023-02-17 09:15:34  magnum.np:INFO [LLG] relax: t=3.2e-10 dE=0.000889859 E=6.43432e-19
# 2023-02-17 09:15:34  magnum.np:INFO [LLG] relax: t=3.3e-10 dE=0.000854029 E=6.42883e-19
# 2023-02-17 09:15:34  magnum.np:INFO [LLG] relax: t=3.4e-10 dE=0.000818591 E=6.42358e-19
# 2023-02-17 09:15:34  magnum.np:INFO [LLG] relax: t=3.5e-10 dE=0.000783309 E=6.41855e-19
# 2023-02-17 09:15:34  magnum.np:INFO [LLG] relax: t=3.6e-10 dE=0.000748751 E=6.41375e-19
# 2023-02-17 09:15:34  magnum.np:INFO [LLG] relax: t=3.7e-10 dE=0.000714682 E=6.40916e-19
# 2023-02-17 09:15:34  magnum.np:INFO [LLG] relax: t=3.8e-10 dE=0.000681267 E=6.4048e-19
# 2023-02-17 09:15:34  magnum.np:INFO [LLG] relax: t=3.9e-10 dE=0.000648431 E=6.40065e-19
# 2023-02-17 09:15:34  magnum.np:INFO [LLG] relax: t=4e-10 dE=0.000616664 E=6.39671e-19
# 2023-02-17 09:15:35  magnum.np:INFO [LLG] relax: t=4.1e-10 dE=0.000585244 E=6.39297e-19
# 2023-02-17 09:15:35  magnum.np:INFO [LLG] relax: t=4.2e-10 dE=0.000555307 E=6.38942e-19
# 2023-02-17 09:15:35  magnum.np:INFO [LLG] relax: t=4.3e-10 dE=0.000526131 E=6.38606e-19
# 2023-02-17 09:15:35  magnum.np:INFO [LLG] relax: t=4.4e-10 dE=0.000497639 E=6.38288e-19
# 2023-02-17 09:15:35  magnum.np:INFO [LLG] relax: t=4.5e-10 dE=0.000470565 E=6.37988e-19
# 2023-02-17 09:15:35  magnum.np:INFO [LLG] relax: t=4.6e-10 dE=0.000444183 E=6.37705e-19
# 2023-02-17 09:15:35  magnum.np:INFO [LLG] relax: t=4.7e-10 dE=0.000418984 E=6.37438e-19
# 2023-02-17 09:15:35  magnum.np:INFO [LLG] relax: t=4.8e-10 dE=0.000394971 E=6.37186e-19
# 2023-02-17 09:15:35  magnum.np:INFO [LLG] relax: t=4.9e-10 dE=0.000371904 E=6.36949e-19
# 2023-02-17 09:15:35  magnum.np:INFO [LLG] relax: t=5e-10 dE=0.000349949 E=6.36726e-19
# 2023-02-17 09:15:35  magnum.np:INFO [LLG] relax: t=5.1e-10 dE=0.000329028 E=6.36517e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=5.2e-10 dE=0.000308899 E=6.3632e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=5.3e-10 dE=0.000290134 E=6.36136e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=5.4e-10 dE=0.000272004 E=6.35963e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=5.5e-10 dE=0.000254997 E=6.358e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=5.6e-10 dE=0.000238873 E=6.35649e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=5.7e-10 dE=0.000223795 E=6.35506e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=5.8e-10 dE=0.000209277 E=6.35373e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=5.9e-10 dE=0.000195971 E=6.35249e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=6e-10 dE=0.000182821 E=6.35133e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=6.1e-10 dE=0.00017121 E=6.35024e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=6.2e-10 dE=0.000159675 E=6.34923e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=6.3e-10 dE=0.000149193 E=6.34828e-19
# 2023-02-17 09:15:36  magnum.np:INFO [LLG] relax: t=6.4e-10 dE=0.000139277 E=6.3474e-19
# 2023-02-17 09:15:37  magnum.np:INFO [LLG] relax: t=6.5e-10 dE=0.000129765 E=6.34657e-19
# 2023-02-17 09:15:37  magnum.np:INFO [LLG] relax: t=6.6e-10 dE=0.000121145 E=6.3458e-19
# 2023-02-17 09:15:37  magnum.np:INFO [LLG] relax: t=6.7e-10 dE=0.000113011 E=6.34509e-19
# 2023-02-17 09:15:37  magnum.np:INFO [LLG] relax: t=6.8e-10 dE=0.000105363 E=6.34442e-19
# 2023-02-17 09:15:37  magnum.np:INFO [LLG] relax: t=6.9e-10 dE=9.80385e-05 E=6.3438e-19
# 2023-02-17 09:15:37  magnum.np:INFO [LLG] relax: t=7e-10 dE=9.12828e-05 E=6.34322e-19
# 2023-02-17 09:15:37  magnum.np:INFO [LLG] relax: t=7.1e-10 dE=8.51773e-05 E=6.34268e-19
# 2023-02-17 09:15:37  magnum.np:INFO [LLG] relax: t=7.2e-10 dE=7.90704e-05 E=6.34218e-19
# 2023-02-17 09:15:37  magnum.np:INFO [LLG] relax: t=7.3e-10 dE=7.38588e-05 E=6.34171e-19
# 2023-02-17 09:15:37  magnum.np:INFO [LLG] relax: t=7.4e-10 dE=6.85646e-05 E=6.34127e-19
# 2023-02-17 09:15:38  magnum.np:INFO [LLG] relax: t=7.5e-10 dE=6.3677e-05 E=6.34087e-19
# 2023-02-17 09:15:38  magnum.np:INFO [LLG] relax: t=7.6e-10 dE=5.95224e-05 E=6.34049e-19
# 2023-02-17 09:15:38  magnum.np:INFO [LLG] relax: t=7.7e-10 dE=5.52039e-05 E=6.34014e-19
# 2023-02-17 09:15:38  magnum.np:INFO [LLG] relax: t=7.8e-10 dE=5.12926e-05 E=6.33982e-19
# 2023-02-17 09:15:38  magnum.np:INFO [LLG] relax: t=7.9e-10 dE=4.77068e-05 E=6.33951e-19
# 2023-02-17 09:15:38  magnum.np:INFO [LLG] relax: t=8e-10 dE=4.43652e-05 E=6.33923e-19
# 2023-02-17 09:15:38  magnum.np:INFO [LLG] relax: t=8.1e-10 dE=4.12679e-05 E=6.33897e-19
# 2023-02-17 09:15:38  magnum.np:INFO [LLG] relax: t=8.2e-10 dE=3.84149e-05 E=6.33873e-19
# 2023-02-17 09:15:38  magnum.np:INFO [LLG] relax: t=8.3e-10 dE=3.54799e-05 E=6.3385e-19
# 2023-02-17 09:15:38  magnum.np:INFO [LLG] relax: t=8.4e-10 dE=3.31973e-05 E=6.33829e-19
# 2023-02-17 09:15:38  magnum.np:INFO [LLG] relax: t=8.5e-10 dE=3.07513e-05 E=6.3381e-19
# 2023-02-17 09:15:38  magnum.np:INFO [LLG] relax: t=8.6e-10 dE=2.85497e-05 E=6.33792e-19
# 2023-02-17 09:15:39  magnum.np:INFO [LLG] relax: t=8.7e-10 dE=2.65112e-05 E=6.33775e-19
# 2023-02-17 09:15:39  magnum.np:INFO [LLG] relax: t=8.8e-10 dE=2.4554e-05 E=6.33759e-19
# 2023-02-17 09:15:39  magnum.np:INFO [LLG] relax: t=8.9e-10 dE=2.2923e-05 E=6.33745e-19
# 2023-02-17 09:15:39  magnum.np:INFO [LLG] relax: t=9e-10 dE=2.12104e-05 E=6.33731e-19
# 2023-02-17 09:15:39  magnum.np:INFO [LLG] relax: t=9.1e-10 dE=1.95792e-05 E=6.33719e-19
# 2023-02-17 09:15:39  magnum.np:INFO [LLG] relax: t=9.2e-10 dE=1.84374e-05 E=6.33707e-19
# 2023-02-17 09:15:39  magnum.np:INFO [LLG] relax: t=9.3e-10 dE=1.69692e-05 E=6.33696e-19
# 2023-02-17 09:15:39  magnum.np:INFO [LLG] relax: t=9.4e-10 dE=1.56642e-05 E=6.33687e-19
# 2023-02-17 09:15:39  magnum.np:INFO [LLG] relax: t=9.5e-10 dE=1.46038e-05 E=6.33677e-19
# 2023-02-17 09:15:39  magnum.np:INFO [LLG] relax: t=9.6e-10 dE=1.35434e-05 E=6.33669e-19
# 2023-02-17 09:15:39  magnum.np:INFO [LLG] relax: t=9.7e-10 dE=1.26461e-05 E=6.33661e-19
# 2023-02-17 09:15:39  magnum.np:INFO [LLG] relax: t=9.8e-10 dE=1.16671e-05 E=6.33653e-19
# 2023-02-17 09:15:40  magnum.np:INFO [LLG] relax: t=9.9e-10 dE=1.08514e-05 E=6.33646e-19
# 2023-02-17 09:15:40  magnum.np:INFO [LLG] relax: t=1e-09 dE=1.00356e-05 E=6.3364e-19
# 2023-02-17 09:15:40  magnum.np:INFO [LLG] relax: t=1.01e-09 dE=9.30136e-06 E=6.33634e-19
# 2023-02-17 09:15:40  magnum.np:INFO [LLGSolver] using RKF45 solver (atol = 1e-05)
# 2023-02-17 09:15:40  magnum.np:INFO [LLG] step: dt= 1e-11  t=1e-11
# 2023-02-17 09:15:40  magnum.np:INFO [LLG] step: dt= 1e-11  t=2e-11
# 2023-02-17 09:15:40  magnum.np:INFO [LLG] step: dt= 1e-11  t=3e-11
# 2023-02-17 09:15:40  magnum.np:INFO [LLG] step: dt= 1e-11  t=4e-11
# 2023-02-17 09:15:40  magnum.np:INFO [LLG] step: dt= 1e-11  t=5e-11
# 2023-02-17 09:15:41  magnum.np:INFO [LLG] step: dt= 1e-11  t=6e-11
# 2023-02-17 09:15:41  magnum.np:INFO [LLG] step: dt= 1e-11  t=7e-11
# 2023-02-17 09:15:41  magnum.np:INFO [LLG] step: dt= 1e-11  t=8e-11
# 2023-02-17 09:15:41  magnum.np:INFO [LLG] step: dt= 1e-11  t=9e-11
# 2023-02-17 09:15:41  magnum.np:INFO [LLG] step: dt= 1e-11  t=1e-10
# 2023-02-17 09:15:41  magnum.np:INFO [LLG] step: dt= 1e-11  t=1.1e-10
# 2023-02-17 09:15:41  magnum.np:INFO [LLG] step: dt= 1e-11  t=1.2e-10
# 2023-02-17 09:15:41  magnum.np:INFO [LLG] step: dt= 1e-11  t=1.3e-10
# 2023-02-17 09:15:42  magnum.np:INFO [LLG] step: dt= 1e-11  t=1.4e-10
# 2023-02-17 09:15:42  magnum.np:INFO [LLG] step: dt= 1e-11  t=1.5e-10
# 2023-02-17 09:15:42  magnum.np:INFO [LLG] step: dt= 1e-11  t=1.6e-10
# 2023-02-17 09:15:42  magnum.np:INFO [LLG] step: dt= 1e-11  t=1.7e-10
# 2023-02-17 09:15:42  magnum.np:INFO [LLG] step: dt= 1e-11  t=1.8e-10
# 2023-02-17 09:15:42  magnum.np:INFO [LLG] step: dt= 1e-11  t=1.9e-10
# 2023-02-17 09:15:42  magnum.np:INFO [LLG] step: dt= 1e-11  t=2e-10
# 2023-02-17 09:15:42  magnum.np:INFO [LLG] step: dt= 1e-11  t=2.1e-10
# 2023-02-17 09:15:42  magnum.np:INFO [LLG] step: dt= 1e-11  t=2.2e-10
# 2023-02-17 09:15:43  magnum.np:INFO [LLG] step: dt= 1e-11  t=2.3e-10
# 2023-02-17 09:15:43  magnum.np:INFO [LLG] step: dt= 1e-11  t=2.4e-10
# 2023-02-17 09:15:43  magnum.np:INFO [LLG] step: dt= 1e-11  t=2.5e-10
# 2023-02-17 09:15:43  magnum.np:INFO [LLG] step: dt= 1e-11  t=2.6e-10
# 2023-02-17 09:15:43  magnum.np:INFO [LLG] step: dt= 1e-11  t=2.7e-10
# 2023-02-17 09:15:43  magnum.np:INFO [LLG] step: dt= 1e-11  t=2.8e-10
# 2023-02-17 09:15:43  magnum.np:INFO [LLG] step: dt= 1e-11  t=2.9e-10
# 2023-02-17 09:15:43  magnum.np:INFO [LLG] step: dt= 1e-11  t=3e-10
# 2023-02-17 09:15:44  magnum.np:INFO [LLG] step: dt= 1e-11  t=3.1e-10
# 2023-02-17 09:15:44  magnum.np:INFO [LLG] step: dt= 1e-11  t=3.2e-10
# 2023-02-17 09:15:44  magnum.np:INFO [LLG] step: dt= 1e-11  t=3.3e-10
# 2023-02-17 09:15:44  magnum.np:INFO [LLG] step: dt= 1e-11  t=3.4e-10
# 2023-02-17 09:15:44  magnum.np:INFO [LLG] step: dt= 1e-11  t=3.5e-10
# 2023-02-17 09:15:44  magnum.np:INFO [LLG] step: dt= 1e-11  t=3.6e-10
# 2023-02-17 09:15:44  magnum.np:INFO [LLG] step: dt= 1e-11  t=3.7e-10
# 2023-02-17 09:15:44  magnum.np:INFO [LLG] step: dt= 1e-11  t=3.8e-10
# 2023-02-17 09:15:45  magnum.np:INFO [LLG] step: dt= 1e-11  t=3.9e-10
# 2023-02-17 09:15:45  magnum.np:INFO [LLG] step: dt= 1e-11  t=4e-10
# 2023-02-17 09:15:45  magnum.np:INFO [LLG] step: dt= 1e-11  t=4.1e-10
# 2023-02-17 09:15:45  magnum.np:INFO [LLG] step: dt= 1e-11  t=4.2e-10
# 2023-02-17 09:15:45  magnum.np:INFO [LLG] step: dt= 1e-11  t=4.3e-10
# 2023-02-17 09:15:45  magnum.np:INFO [LLG] step: dt= 1e-11  t=4.4e-10
# 2023-02-17 09:15:45  magnum.np:INFO [LLG] step: dt= 1e-11  t=4.5e-10
# 2023-02-17 09:15:45  magnum.np:INFO [LLG] step: dt= 1e-11  t=4.6e-10
# 2023-02-17 09:15:45  magnum.np:INFO [LLG] step: dt= 1e-11  t=4.7e-10
# 2023-02-17 09:15:46  magnum.np:INFO [LLG] step: dt= 1e-11  t=4.8e-10
# 2023-02-17 09:15:46  magnum.np:INFO [LLG] step: dt= 1e-11  t=4.9e-10
# 2023-02-17 09:15:46  magnum.np:INFO [LLG] step: dt= 1e-11  t=5e-10
# 2023-02-17 09:15:46  magnum.np:INFO [LLG] step: dt= 1e-11  t=5.1e-10
# 2023-02-17 09:15:46  magnum.np:INFO [LLG] step: dt= 1e-11  t=5.2e-10
# 2023-02-17 09:15:46  magnum.np:INFO [LLG] step: dt= 1e-11  t=5.3e-10
# 2023-02-17 09:15:46  magnum.np:INFO [LLG] step: dt= 1e-11  t=5.4e-10
# 2023-02-17 09:15:46  magnum.np:INFO [LLG] step: dt= 1e-11  t=5.5e-10
# 2023-02-17 09:15:47  magnum.np:INFO [LLG] step: dt= 1e-11  t=5.6e-10
# 2023-02-17 09:15:47  magnum.np:INFO [LLG] step: dt= 1e-11  t=5.7e-10
# 2023-02-17 09:15:47  magnum.np:INFO [LLG] step: dt= 1e-11  t=5.8e-10
# 2023-02-17 09:15:47  magnum.np:INFO [LLG] step: dt= 1e-11  t=5.9e-10
# 2023-02-17 09:15:47  magnum.np:INFO [LLG] step: dt= 1e-11  t=6e-10
# 2023-02-17 09:15:47  magnum.np:INFO [LLG] step: dt= 1e-11  t=6.1e-10
# 2023-02-17 09:15:47  magnum.np:INFO [LLG] step: dt= 1e-11  t=6.2e-10
# 2023-02-17 09:15:47  magnum.np:INFO [LLG] step: dt= 1e-11  t=6.3e-10
# 2023-02-17 09:15:48  magnum.np:INFO [LLG] step: dt= 1e-11  t=6.4e-10
# 2023-02-17 09:15:48  magnum.np:INFO [LLG] step: dt= 1e-11  t=6.5e-10
# 2023-02-17 09:15:48  magnum.np:INFO [LLG] step: dt= 1e-11  t=6.6e-10
# 2023-02-17 09:15:48  magnum.np:INFO [LLG] step: dt= 1e-11  t=6.7e-10
# 2023-02-17 09:15:48  magnum.np:INFO [LLG] step: dt= 1e-11  t=6.8e-10
# 2023-02-17 09:15:48  magnum.np:INFO [LLG] step: dt= 1e-11  t=6.9e-10
# 2023-02-17 09:15:48  magnum.np:INFO [LLG] step: dt= 1e-11  t=7e-10
# 2023-02-17 09:15:48  magnum.np:INFO [LLG] step: dt= 1e-11  t=7.1e-10
# 2023-02-17 09:15:48  magnum.np:INFO [LLG] step: dt= 1e-11  t=7.2e-10
# 2023-02-17 09:15:49  magnum.np:INFO [LLG] step: dt= 1e-11  t=7.3e-10
# 2023-02-17 09:15:49  magnum.np:INFO [LLG] step: dt= 1e-11  t=7.4e-10
# 2023-02-17 09:15:49  magnum.np:INFO [LLG] step: dt= 1e-11  t=7.5e-10
# 2023-02-17 09:15:49  magnum.np:INFO [LLG] step: dt= 1e-11  t=7.6e-10
# 2023-02-17 09:15:49  magnum.np:INFO [LLG] step: dt= 1e-11  t=7.7e-10
# 2023-02-17 09:15:49  magnum.np:INFO [LLG] step: dt= 1e-11  t=7.8e-10
# 2023-02-17 09:15:49  magnum.np:INFO [LLG] step: dt= 1e-11  t=7.9e-10
# 2023-02-17 09:15:50  magnum.np:INFO [LLG] step: dt= 1e-11  t=8e-10
# 2023-02-17 09:15:50  magnum.np:INFO [LLG] step: dt= 1e-11  t=8.1e-10
# 2023-02-17 09:15:50  magnum.np:INFO [LLG] step: dt= 1e-11  t=8.2e-10
# 2023-02-17 09:15:50  magnum.np:INFO [LLG] step: dt= 1e-11  t=8.3e-10
# 2023-02-17 09:15:50  magnum.np:INFO [LLG] step: dt= 1e-11  t=8.4e-10
# 2023-02-17 09:15:50  magnum.np:INFO [LLG] step: dt= 1e-11  t=8.5e-10
# 2023-02-17 09:15:50  magnum.np:INFO [LLG] step: dt= 1e-11  t=8.6e-10
# 2023-02-17 09:15:51  magnum.np:INFO [LLG] step: dt= 1e-11  t=8.7e-10
# 2023-02-17 09:15:51  magnum.np:INFO [LLG] step: dt= 1e-11  t=8.8e-10
# 2023-02-17 09:15:51  magnum.np:INFO [LLG] step: dt= 1e-11  t=8.9e-10
# 2023-02-17 09:15:51  magnum.np:INFO [LLG] step: dt= 1e-11  t=9e-10
# 2023-02-17 09:15:51  magnum.np:INFO [LLG] step: dt= 1e-11  t=9.1e-10
# 2023-02-17 09:15:51  magnum.np:INFO [LLG] step: dt= 1e-11  t=9.2e-10
# 2023-02-17 09:15:51  magnum.np:INFO [LLG] step: dt= 1e-11  t=9.3e-10
# 2023-02-17 09:15:51  magnum.np:INFO [LLG] step: dt= 1e-11  t=9.4e-10
# 2023-02-17 09:15:52  magnum.np:INFO [LLG] step: dt= 1e-11  t=9.5e-10
# 2023-02-17 09:15:52  magnum.np:INFO [LLG] step: dt= 1e-11  t=9.6e-10
# 2023-02-17 09:15:52  magnum.np:INFO [LLG] step: dt= 1e-11  t=9.7e-10
# 2023-02-17 09:15:52  magnum.np:INFO [LLG] step: dt= 1e-11  t=9.8e-10
# 2023-02-17 09:15:52  magnum.np:INFO [LLG] step: dt= 1e-11  t=9.9e-10
# 2023-02-17 09:15:52  magnum.np:INFO [LLG] step: dt= 1e-11  t=1e-09
# ====================================================================================
# TIMER REPORT
# ====================================================================================
# Operation              No of calls    Avg time [ms]    Total time [s]    Memory [MB]
# -------------------  -------------  ---------------  ----------------  -------------
# LLGSolver.relax                  1     9155.99              9.15599         5.66406
#     DemagField.h              3882        1.04335           4.05028         5.47266
#     ExchangeField.h           3882        0.838581          3.25537         0.113281
# LLGSolver.step                 100      125.402            12.5402          0
#     DemagField.h              4674        1.06044           4.95649         0
#     ExchangeField.h           4674        0.928253          4.33865         0
#     ExternalField.h           4674        0.0521858         0.243917        0
# -------------------  -------------  ---------------  ----------------  -------------
# Total                                                      21.7681
# Missing                                                     0.0719764
# ====================================================================================

# %% [markdown]
# ## Plot Results

# %%
#TODO: read latest script content from gitlab repository, as soon as %load works with Colab

import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("data/log.dat")
ref = np.loadtxt("ref/m.dat")

fig, ax = plt.subplots(figsize=(15, 5))
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
ax.plot(data[:,0]*1e9, data[:,1], '-', color = cycle[0], label = "magnum.np - x")
ax.plot(ref[:,0]*1e9, ref[:,1], '-', color = cycle[0], linewidth = 6, alpha = 0.4, label = "reference - x")

ax.plot(data[:,0]*1e9, data[:,2], '-', color = cycle[1], label = "magnum.np - y")
ax.plot(ref[:,0]*1e9, ref[:,2], '-', color = cycle[1], linewidth = 6, alpha = 0.4, label = "reference - y")

ax.plot(data[:,0]*1e9, data[:,3], '-', color = cycle[2], label = "magnum.np - z")
ax.plot(ref[:,0]*1e9, ref[:,3], '-', color = cycle[2], linewidth = 6, alpha = 0.4, label = "reference - z")

ax.set_xlim([0,1])
ax.set_xlabel("Time t[ns]")
ax.set_ylabel("Magnetization $m$")
ax.legend(ncol=3)
ax.grid()
fig.savefig("data/results.png")
